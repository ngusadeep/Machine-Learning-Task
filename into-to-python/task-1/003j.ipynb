# %%
from fscores import new_stdsscores

fmDict = {}
new_stdsscores
# Out:
# [[1, 59.4, 26.3, 81.8, 41.2, 61.5, 'B+', 'P'],
#  [2, 65.9, 29.6, 100, 45.9, 73.0, 'A', 'P'],
#  [3, 70.7, 56.3, 70.5, 62.8, 66.7, 'B+', 'P'],
#  [4, 27.5, 19.4, 36.7, 23.0, 29.9, 'E', 'F'],
#  [5, 45.2, 27.4, 96.4, 35.4, 65.9, 'B+', 'P'],
#  [6, 65.7, 29.1, 80.4, 45.6, 63.0, 'B+', 'P'],
#  [7, 88.2, 31.2, 77.8, 56.9, 67.3, 'B+', 'P'],
#  [8, 82.6, 70.9, 71.3, 76.2, 73.8, 'A', 'P'],
#  [9, 58.6, 52.2, 31, 55.1, 43.0, 'C', 'P'],
#  [10, 84.1, 71.5, 25.1, 77.2, 51.2, 'B', 'P'],
#  [11, 84.5, 78.7, 93.4, 81.3, 87.3, 'A', 'P'],
#  [12, 63.6, 67.5, 63.9, 65.7, 64.8, 'B+', 'P'],
#  [13, 15.7, 11.1, 82.5, 13.2, 47.9, 'C', 'P'],
#  [14, 76.8, 23.4, 99, 47.4, 73.2, 'A', 'P'],
#  [15, 99.8, 38.7, 78.5, 66.2, 72.3, 'A', 'P'],
#  [16, 29.5, 95.2, 96.4, 65.6, 81.0, 'A', 'P'],
#  [17, 36.3, 28.8, 56.6, 32.2, 44.4, 'C', 'P'],
#  [18, 79.4, 96.4, 15.7, 88.8, 52.2, 'B', 'P'],
#  [19, 75, 12.2, 72.1, 40.5, 56.3, 'B', 'P'],
#  [20, 95.1, 83.3, 47, 88.6, 67.8, 'B+', 'P'],
# ...

# %%
index = 1  
s_n_index = 0      
sorted_scores = sorted(new_stdsscores, key=lambda x: x[index], reverse=True)

top_5 = sorted_scores[:5]


highest_5_s_n = [row[s_n_index] for row in top_5]
highest_5_values = [row[index] for row in top_5]

print(f"top 5 highest by FM are:")
for s_n, score in zip(highest_5_s_n, highest_5_values):
    print(f"student {s_n}: {score}")
# Out:
# top 5 highest by FM are:
# student 15: 99.8
# student 36: 99
# student 200: 99
# student 156: 98.7
# student 83: 98.1
